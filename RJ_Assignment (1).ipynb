# %%
#Importing required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('2015.csv')
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
#Duplicates
duplicatess = {}

for column in df.columns:
  duplicatess_cnt = df[column].duplicated().sum()
  duplicatess[column] = duplicatess_cnt

print("Number of duplicate values:")
print(duplicatess)
# Out:
# Number of duplicate values:
# {'Country': 0, 'Region': 148, 'Happiness Rank': 1, 'Happiness Score': 1, 'Standard Error': 5, 'Economy (GDP per Capita)': 0, 'Family': 0, 'Health (Life Expectancy)': 1, 'Freedom': 0, 'Trust (Government Corruption)': 1, 'Generosity': 0, 'Dystopia Residual': 0}

# %%
#missing Values
no_of_missing_values= df.isna().sum()
no_of_missing_values
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
#To get the number of columns and rows
df.shape
# Out:
# (158, 12)

# %%
#To understand column headings
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
#Unique_values-each variable.
for column in df.columns:
  unique_value=df[column].unique()
  print(f"The unique values, '{column}' is:")
  print(unique_value)
# Out:
# The unique values, 'Country' is:
# ['Switzerland' 'Iceland' 'Denmark' 'Norway' 'Canada' 'Finland'
#  'Netherlands' 'Sweden' 'New Zealand' 'Australia' 'Israel' 'Costa Rica'
#  'Austria' 'Mexico' 'United States' 'Brazil' 'Luxembourg' 'Ireland'
#  'Belgium' 'United Arab Emirates' 'United Kingdom' 'Oman' 'Venezuela'
#  'Singapore' 'Panama' 'Germany' 'Chile' 'Qatar' 'France' 'Argentina'
#  'Czech Republic' 'Uruguay' 'Colombia' 'Thailand' 'Saudi Arabia' 'Spain'
#  'Malta' 'Taiwan' 'Kuwait' 'Suriname' 'Trinidad and Tobago' 'El Salvador'
#  'Guatemala' 'Uzbekistan' 'Slovakia' 'Japan' 'South Korea' 'Ecuador'
#  'Bahrain' 'Italy' 'Bolivia' 'Moldova' 'Paraguay' 'Kazakhstan' 'Slovenia'
#  'Lithuania' 'Nicaragua' 'Peru' 'Belarus' 'Poland' 'Malaysia' 'Croatia'
#  'Libya' 'Russia' 'Jamaica' 'North Cyprus' 'Cyprus' 'Algeria' 'Kosovo'
#  'Turkmenistan' 'Mauritius' 'Hong Kong' 'Estonia' 'Indonesia' 'Vietnam'
#  'Turkey' 'Kyrgyzstan' 'Nigeria' 'Bhutan' 'Azerbaijan' 'Pakistan' 'Jordan'
# ...

# %%
#Begin pie chart
#calculating average
regional_happiness = df.groupby('Region')['Happiness Score'].mean()
print(regional_happiness)

# Plotting the Pie Chart
plt.figure(figsize=(6, 6))
plt.pie(regional_happiness, labels=regional_happiness.index, autopct='%1.2f%%',
        wedgeprops={'edgecolor': 'black', 'linewidth': 1.5})
plt.title('Average Happiness Scores by Region',fontsize=14, pad=20)
plt.axis('equal')  # For making pie chart circular

plt.show()
# Out:
# Region
# Australia and New Zealand          7.285000
# Central and Eastern Europe         5.332931
# Eastern Asia                       5.626167
# Latin America and Caribbean        6.144682
# Middle East and Northern Africa    5.406900
# North America                      7.273000
# Southeastern Asia                  5.317444
# Southern Asia                      4.580857
# Sub-Saharan Africa                 4.202800
# Western Europe                     6.689619
# Name: Happiness Score, dtype: float64

# %%
#Now lets plot Scatter plot
#Sorting Government corruption
Govt_Corruption_order= df.sort_values(by='Trust (Government Corruption)', ascending=False)
print(Govt_Corruption_order[['Country', 'Trust (Government Corruption)']])
#plotting Scatter plot
plt.scatter(df['Economy (GDP per Capita)'], df['Trust (Government Corruption)'])
plt.xlabel('Economy (GDP per Capita)',fontsize=12)
plt.grid(True)
plt.ylabel('Trust (Government Corruption)',fontsize=12)
plt.title('Economy vs. Trust',fontsize=14)
plt.show()
# Out:
#                     Country  Trust (Government Corruption)
# 153                  Rwanda                        0.55191
# 27                    Qatar                        0.52208
# 23                Singapore                        0.49210
# 2                   Denmark                        0.48357
# 7                    Sweden                        0.43844
# ..                      ...                            ...
# 55                Lithuania                        0.01031
# 133                Bulgaria                        0.00872
# 85                  Romania                        0.00649
# 95   Bosnia and Herzegovina                        0.00227
# 73                Indonesia                        0.00000
#
# [158 rows x 2 columns]

# %%
#Begin Heat map.
#Selecting the required columns
Heading = ['Happiness Rank', 'Happiness Score',
       'Standard Error', 'Economy (GDP per Capita)', 'Family',
       'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
       'Generosity', 'Dystopia Residual']
required_data=df[Heading]

# %%
# Calculate correlation matrix
correlation_matrix = Heading.corr()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 2
#       1 # Calculate correlation matrix
# ----> 2 correlation_matrix = Heading.corr()
#
# AttributeError: 'list' object has no attribute 'corr'

# %%
# Create heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", square=True)
plt.title('Correlation Heatmap')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 3
#       1 # Create heatmap
#       2 plt.figure(figsize=(10, 6))
# ----> 3 sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", square=True)
#       4 plt.title('Correlation Heatmap')
#       5 plt.show()
#
# NameError: name 'correlation_matrix' is not defined
